# %% [markdown]
# # Exercises I

# %%
import pandas as pd
import numpy as np
from pydataset import data

# %% [markdown]
# ### Create a notebook or python script named advanced_dataframes to do your work in for these exercises.
#
# 1. Run python -m pip install pymysql from your terminal to install the mysql client (any folder is fine)
#
# 2. cd into your exercises folder for this module and run echo env.py >> .gitignore

# %% [markdown]
# 3. Create a function named get_db_url. It should accept a username, hostname, password, and database name and return a url connection string formatted like in the example at the start of this lesson.

# %%
import env

# %%
import env
def get_db_url(db_name):
    connection_url = f"mysql+pymysql://{env.user}:{env.password}@{env.host}/{db_name}"
    
    return connection_url

# %% [markdown]
# 4. Use your function to obtain a connection to the employees database.

# %%
url = get_db_url('employees')

# %%
pd.read_sql('select * from employees limit 100', url)
# Out:
#     emp_no  birth_date   first_name     last_name gender   hire_date
# 0    10001  1953-09-02       Georgi       Facello      M  1986-06-26
# 1    10002  1964-06-02      Bezalel        Simmel      F  1985-11-21
# 2    10003  1959-12-03        Parto       Bamford      M  1986-08-28
# 3    10004  1954-05-01    Chirstian       Koblick      M  1986-12-01
# 4    10005  1955-01-21      Kyoichi      Maliniak      M  1989-09-12
# 5    10006  1953-04-20       Anneke       Preusig      F  1989-06-02
# 6    10007  1957-05-23      Tzvetan     Zielinski      F  1989-02-10
# 7    10008  1958-02-19       Saniya      Kalloufi      M  1994-09-15
# 8    10009  1952-04-19       Sumant          Peac      F  1985-02-18
# 9    10010  1963-06-01    Duangkaew      Piveteau      F  1989-08-24
# 10   10011  1953-11-07         Mary         Sluis      F  1990-01-22
# 11   10012  1960-10-04     Patricio     Bridgland      M  1992-12-18
# 12   10013  1963-06-07    Eberhardt        Terkki      M  1985-10-20
# ...

# %% [markdown]
# 5. Once you have successfully run a query:
#
#    a. Intentionally make a typo in the database url. What kind of error message do you see?
#
#    b. Intentionally make an error in your SQL query. What does the error message look like?

# %%
pd.read_sql('select * from employees limit 10', url)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    3279 try:
# -> 3280     return fn()
#    3281 except dialect.dbapi.Error as e:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/pool/base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/pool/base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# ...

# %% [markdown]
# ![Screenshot 2023-10-04 at 10.08.22 AM.png](attachment:f107a3f2-198d-413c-95c3-d76765de4239.png)

# %% [markdown]
# OperationalError: (pymysql.err.OperationalError) (1044, "Access denied for user 'tobias_2307'@'%' to database 'employee'")
# {Backaround on this error at httos.Hsalalche…melel14/eßa8)

# %%
pd.read_sql('select all from employees limit 100', url)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# ...

# %% [markdown]
# ![image.png](attachment:631b095e-2ef1-48eb-88a2-6df385e7ecc3.png)

# %% [markdown]
# 6. Read the employees and titles tables into two separate DataFrames.

# %%
df_employees = pd.read_sql('select * from employees', url)
df_employees
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %%
df_titles = pd.read_sql('select * from titles', url)
df_titles
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %% [markdown]
# 7. How many rows and columns do you have in each DataFrame? Is that what you expected?

# %%
# 300024 rows × 6 columns for employees db
df_employees.shape
# Out:
# (300024, 6)

# %%
# 443308 rows × 4 columns for titles db
df_titles.shape
# Out:
# (443308, 4)

# %% [markdown]
# 8. Display the summary statistics for each DataFrame.

# %%
df_employees = pd.read_sql('select * from employees.employees', url)
df_employees.describe()
# Out:
#               emp_no
# count  300024.000000
# mean   253321.763392
# std    161828.235540
# min     10001.000000
# 25%     85006.750000
# 50%    249987.500000
# 75%    424993.250000
# max    499999.000000

# %%
df_employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300024 entries, 0 to 300023
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   emp_no      300024 non-null  int64
#  1   birth_date  300024 non-null  object
#  2   first_name  300024 non-null  object
#  3   last_name   300024 non-null  object
#  4   gender      300024 non-null  object
#  5   hire_date   300024 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 13.7+ MB

# %%
df_titles = pd.read_sql('select * from employees.titles', url)
df_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443308 entries, 0 to 443307
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   emp_no     443308 non-null  int64
#  1   title      443308 non-null  object
#  2   from_date  443308 non-null  object
#  3   to_date    443308 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 13.5+ MB

# %%
df_titles.describe()
# Out:
#               emp_no
# count  443308.000000
# mean   253075.034430
# std    161853.292613
# min     10001.000000
# 25%     84855.750000
# 50%    249847.500000
# 75%    424891.250000
# max    499999.000000

# %% [markdown]
# 9. How many unique titles are in the titles DataFrame?

# %%
uni_titles = np.unique(df_titles.title)
len(uni_titles)
# Out:
# 7

# %%
df_titles.title.nunique()
# Out:
# 7

# %%
df_titles.nunique()
# Out:
# emp_no       300024
# title             7
# from_date      6393
# to_date        5888
# dtype: int64

# %% [markdown]
# 10. What is the oldest date in the to_date column?

# %%
np.min(df_titles.to_date)
# Out:
# datetime.date(1985, 3, 1)

# %% [markdown]
# 11. What is the most recent date in the to_date column?

# %%
np.max(df_titles.to_date)
# Out:
# datetime.date(9999, 1, 1)

# %%
df_titles[df_titles.to_date != df_titles.to_date.max()].to_date.max()
# Out:
# datetime.date(2002, 8, 1)

# %% [markdown]
# # Exercises II

# %% [markdown]
# ### 1. Copy the users and roles DataFrames from the examples above.

# %%
# Create the users DataFrame.

users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
# Create the roles DataFrame

roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %% [markdown]
# ### 2. What is the result of using a right join on the DataFrames?

# %%
pd.merge(users, roles, how='right', left_on='role_id', right_on='id')
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0     1      admin
# 1   2.0    joe      2.0     2     author
# 2   3.0  sally      3.0     3   reviewer
# 3   4.0   adam      3.0     3   reviewer
# 4   NaN    NaN      NaN     4  commenter

# %% [markdown]
# ### 3. What is the result of using an outer join on the DataFrames?

# %%
pd.merge(users, roles, how='outer', left_on='role_id', right_on='id')
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0   1.0      admin
# 1   2.0    joe      2.0   2.0     author
# 2   3.0  sally      3.0   3.0   reviewer
# 3   4.0   adam      3.0   3.0   reviewer
# 4   5.0   jane      NaN   NaN        NaN
# 5   6.0   mike      NaN   NaN        NaN
# 6   NaN    NaN      NaN   4.0  commenter

# %% [markdown]
# ### 4. What happens if you drop the foreign keys from the DataFrames and try to merge them?

# %%
pd.merge(users, roles, how='outer')

# it stacks both tables after each other (vetivally), mixing data that is not constant.  since we dont specify how it should be merged.
# Out:
#    id       name  role_id
# 0   1        bob      1.0
# 1   2        joe      2.0
# 2   3      sally      3.0
# 3   4       adam      3.0
# 4   5       jane      NaN
# 5   6       mike      NaN
# 6   1      admin      NaN
# 7   2     author      NaN
# 8   3   reviewer      NaN
# 9   4  commenter      NaN

# %% [markdown]
# ### 5. Load the mpg dataset from PyDataset.

# %%
mpg = data('mpg')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %% [markdown]
# ### 6. Output and read the documentation for the mpg dataset.

# %%
data('mpg', show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %% [markdown]
# ### 7. How many rows and columns are in the dataset?

# %%
mpg.shape
# Out:
# (234, 11)

# %% [markdown]
# ### 8. Check out your column names and perform any cleanup you may want on them.

# %%
mpg.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'class'],
#       dtype='object')

# %%
#mpg = mpg.rename({'manufacturer':'man'})
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  avg_mileage  is_automatic  mileage_difference
# ...

# %% [markdown]
# ### 9. Display the summary statistics for the dataset.

# %%
mpg.describe(include = 'all')
# Out:
#        manufacturer        model       displ         year         cyl  \
# count           234          234  234.000000   234.000000  234.000000
# unique           15           38         NaN          NaN         NaN
# top           dodge  caravan 2wd         NaN          NaN         NaN
# freq             37           11         NaN          NaN         NaN
# mean            NaN          NaN    3.471795  2003.500000    5.888889
# std             NaN          NaN    1.291959     4.509646    1.611534
# min             NaN          NaN    1.600000  1999.000000    4.000000
# 25%             NaN          NaN    2.400000  1999.000000    4.000000
# 50%             NaN          NaN    3.300000  2003.500000    6.000000
# 75%             NaN          NaN    4.600000  2008.000000    8.000000
# max             NaN          NaN    7.000000  2008.000000    8.000000
#
#            trans  drv         cty         hwy   fl class  avg_mileage  \
# ...

# %% [markdown]
# ### 10. How many different manufacturers are there?

# %%
len(mpg.manufacturer.unique())
# Out:
# 15

# %%
mpg.manufacturer.nunique()
# Out:
# 15

# %% [markdown]
# ### 11. How many different models are there?

# %%
len(mpg.model.unique())
# Out:
# 38

# %%
mpg.model.nunique()
# Out:
# 38

# %% [markdown]
# ### 12. Create a column named mileage_difference like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car.

# %%
mpg['mileage_difference'] = mpg.hwy - mpg.cty
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  avg_mileage  is_automatic  mileage_difference
# ...

# %% [markdown]
# ### 13. Create a column named average_mileage like you did in the DataFrames exercises; this is the mean of the city and highway mileage.

# %%
mpg['avg_mileage'] = (mpg.cty + mpg.hwy) / 2
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  avg_mileage
# 1    compact         23.5
# 2    compact         25.0
# ...

# %%
mpg[['cty','hwy']].agg('mean', axis=1)
# Out:
# 1      23.5
# 2      25.0
# 3      25.5
# 4      25.5
# 5      21.0
#        ...
# 230    23.5
# 231    25.0
# 232    21.0
# 233    22.0
# 234    21.5
# Length: 234, dtype: float64

# %%
# mpg['average_milage'] = mpg[['cty','hwy']].agg('mean', axis=1)
# mpg

# %% [markdown]
# ### 14. Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.

# %%
def is_automatic(transmission):
    if 'auto' in transmission.lower():
        return True
    else:
        return False

# %%
mpg['is_automatic'] = mpg['trans'].apply(is_automatic)

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  avg_mileage  is_automatic
# 1    compact         23.5          True
# ...

# %%
mpg.trans.str.contains('auto')
# Out:
# 1       True
# 2      False
# 3      False
# 4       True
# 5       True
#        ...
# 230     True
# 231    False
# 232     True
# 233    False
# 234     True
# Name: trans, Length: 234, dtype: bool

# %%
np.where(mpg.trans.str.contains('auto'), 'Y' ,'N')
# Out:
# array(['Y', 'N', 'N', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'N',
#        'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N',
#        'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'N', 'Y', 'Y', 'N', 'N', 'Y', 'N', 'N', 'Y', 'N', 'N', 'Y',
#        'N', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'N',
#        'N', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'N', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'N', 'N', 'Y',
# ...

# %%
# mpg['is_auto'] = mpg.trans.str.contains('auto')

# %% [markdown]
# ### 15. Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?

# %%
mpg.groupby('manufacturer').mean().avg_mileage.sort_values().tail(1)
# Out:
# /var/folders/w8/3pzw7rq50zv8f2wgdz4pgqdr0000gn/T/ipykernel_6004/3591529549.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mpg.groupby('manufacturer').mean().avg_mileage.sort_values().tail(1)
# manufacturer
# honda    28.5
# Name: avg_mileage, dtype: float64

# %%
mpg.groupby('manufacturer').mean().avg_mileage.nlargest(1)
# Out:
# /var/folders/w8/3pzw7rq50zv8f2wgdz4pgqdr0000gn/T/ipykernel_6004/420784400.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mpg.groupby('manufacturer').mean().avg_mileage.nlargest(1)
# manufacturer
# honda    28.5
# Name: avg_mileage, dtype: float64

# %% [markdown]
# ### 16. Do automatic or manual cars have better miles per gallon?

# %%
mpg.groupby('is_automatic').mean().avg_mileage.head()
# Out:
# /var/folders/w8/3pzw7rq50zv8f2wgdz4pgqdr0000gn/T/ipykernel_6004/3241835277.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mpg.groupby('is_automatic').mean().avg_mileage.head()
# is_automatic
# False    22.227273
# True     19.130573
# Name: avg_mileage, dtype: float64

# %%
mpg['trans'].max()
# Out:
# 'manual(m6)'

# %% [markdown]
# # Exercises III

# %% [markdown]
# ### 1. Use your get_db_url function to help you explore the data from the chipotle database.

# %%
url_chipotle = get_db_url('chipotle')
orders = pd.read_sql('select * from orders', url_chipotle)
orders
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  4622 non-null   int64
#  1   order_id            4622 non-null   int64
#  2   quantity            4622 non-null   int64
#  3   item_name           4622 non-null   object
#  4   choice_description  4622 non-null   object
#  5   item_price          4622 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 216.8+ KB

# %%
orders.describe()
# Out:
#                 id     order_id     quantity
# count  4622.000000  4622.000000  4622.000000
# mean   2311.500000   927.254868     1.075725
# std    1334.400802   528.890796     0.410186
# min       1.000000     1.000000     1.000000
# 25%    1156.250000   477.250000     1.000000
# 50%    2311.500000   926.000000     1.000000
# 75%    3466.750000  1393.000000     1.000000
# max    4622.000000  1834.000000    15.000000

# %%
orders.describe(include=object)
# Out:
#            item_name choice_description item_price
# count           4622               4622       4622
# unique            50               1044         78
# top     Chicken Bowl                nan     $8.75
# freq             726               1246        730

# %% [markdown]
# ### 2. What is the total price for each order?

# %%
orders.item_price = orders.item_price.str.replace('$', '').str.replace(',', '').astype(float)
orders
# Out:
# /var/folders/w8/3pzw7rq50zv8f2wgdz4pgqdr0000gn/T/ipykernel_6004/2525338800.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   orders.item_price = orders.item_price.str.replace('$', '').str.replace(',', '').astype(float)
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# ...

# %%
orders['total_price_by_order_id'] = orders.groupby('order_id').item_price.transform(sum)
orders
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %% [markdown]
# ### 3. What are the most popular 3 items?

# %%
orders.groupby('item_name').quantity.sum().nlargest(3)
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Name: quantity, dtype: int64

# %% [markdown]
# ### 4. Which item has produced the most revenue?

# %%
orders.groupby('item_name').item_price.sum().nlargest(1)
# Out:
# item_name
# Chicken Bowl    7342.73
# Name: item_price, dtype: float64

# %% [markdown]
# ### 5. Join the employees and titles DataFrames together.

# %%
emp_titles_uni = pd.merge(df_employees, df_titles, how ='outer', on ='emp_no')
emp_titles_uni
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title   from_date     to_date
# 0       Senior Engineer  1986-06-26  9999-01-01
# 1                 Staff  1996-08-03  9999-01-01
# ...

# %% [markdown]
# ### 6. For each title, find the hire date of the employee that was hired most recently with that title.

# %%
emp_titles_uni.groupby('title').hire_date.max()
# Out:
# title
# Assistant Engineer    1999-12-24
# Engineer              2000-01-28
# Manager               1992-02-05
# Senior Engineer       2000-01-01
# Senior Staff          2000-01-13
# Staff                 2000-01-12
# Technique Leader      1999-12-31
# Name: hire_date, dtype: object

# %% [markdown]
# ### 7. Write the code necessary to create a cross tabulation of the number of titles by department. (Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)

# %%
emp_titles_uni.title.value_counts()
# Out:
# Engineer              115003
# Staff                 107391
# Senior Engineer        97750
# Senior Staff           92853
# Technique Leader       15159
# Assistant Engineer     15128
# Manager                   24
# Name: title, dtype: int64

# %%
departments = pd.read_sql('SELECT * FROM departments', url)
departments
# Out:
#   dept_no           dept_name
# 0    d009    Customer Service
# 1    d005         Development
# 2    d002             Finance
# 3    d003     Human Resources
# 4    d001           Marketing
# 5    d004          Production
# 6    d006  Quality Management
# 7    d008            Research
# 8    d007               Sales

# %%
dept_emp = pd.read_sql('SELECT * FROM dept_emp', url)
dept_emp
# Out:
#         emp_no dept_no   from_date     to_date
# 0        10001    d005  1986-06-26  9999-01-01
# 1        10002    d007  1996-08-03  9999-01-01
# 2        10003    d004  1995-12-03  9999-01-01
# 3        10004    d004  1986-12-01  9999-01-01
# 4        10005    d003  1989-09-12  9999-01-01
# ...        ...     ...         ...         ...
# 331598  499995    d004  1997-06-02  9999-01-01
# 331599  499996    d004  1996-05-13  9999-01-01
# 331600  499997    d005  1987-08-30  9999-01-01
# 331601  499998    d002  1993-12-27  9999-01-01
# 331602  499999    d004  1997-11-30  9999-01-01
#
# [331603 rows x 4 columns]

# %%
emp_title_dept_no = pd.merge(emp_titles_uni, dept_emp, left_on='emp_no', right_on='emp_no', how='left')
emp_title_dept_no
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 489898  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 489899  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 489900  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 489901  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 489902  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title from_date_x   to_date_x dept_no from_date_y  \
# 0       Senior Engineer  1986-06-26  9999-01-01    d005  1986-06-26
# ...

# %%
emp_title_dept = pd.merge(emp_title_dept_no, departments, left_on='dept_no', right_on='dept_no', how='left')
emp_title_dept
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 489898  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 489899  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 489900  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 489901  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 489902  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title from_date_x   to_date_x dept_no from_date_y  \
# 0       Senior Engineer  1986-06-26  9999-01-01    d005  1986-06-26
# ...

# %%
pd.crosstab(emp_title_dept.dept_name, emp_title_dept.title)
# Out:
# title               Assistant Engineer  Engineer  Manager  Senior Engineer  \
# dept_name
# Customer Service                   298      2362        4             2027
# Development                       7769     58135        2            49326
# Finance                              0         0        2                0
# Human Resources                      0         0        2                0
# Marketing                            0         0        2                0
# Production                        6445     49649        4            42205
# Quality Management                1831     13852        4            11864
# Research                           378      2986        2             2570
# Sales                                0         0        2                0
#
# title               Senior Staff  Staff  Technique Leader
# dept_name
# Customer Service           13925  16150               309
# Development                 1247   1424              7683
# ...

# %%
pd.crosstab(emp_title_dept.dept_name, emp_title_dept.title).T
# Out:
# dept_name           Customer Service  Development  Finance  Human Resources  \
# title
# Assistant Engineer               298         7769        0                0
# Engineer                        2362        58135        0                0
# Manager                            4            2        2                2
# Senior Engineer                 2027        49326        0                0
# Senior Staff                   13925         1247    12139            12274
# Staff                          16150         1424    13929            14342
# Technique Leader                 309         7683        0                0
#
# dept_name           Marketing  Production  Quality Management  Research  Sales
# title
# Assistant Engineer          0        6445                1831       378      0
# Engineer                    0       49649               13852      2986      0
# Manager                     2           4                   4         2      2
# ...
