# %% [markdown]
# ### 1. Copy the code from the lesson to create a dataframe full of student grades.

# %%
from pydataset import data
import pandas as pd
import numpy as np

np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### a. Create a column named passing_english that indicates whether each student has a passing grade in english.

# %%
df["passing_english"] = df.english >69
df
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True
# 11     Alan    92       62       72            False

# %%
passing_eng = df.english >69

# %% [markdown]
# #### b. Sort the english grades by the passing_english column. How are duplicates handled?

# %%
df.sort_values('passing_english', ascending=False)
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False

# %% [markdown]
# #### c. Sort the english grades first by passing_english and then by student name. All the students that are failing english should be first, and within the students that are failing english they should be ordered alphabetically. The same should be true for the students passing english. (Hint: you can pass a list to the .sort_values method)

# %%
df.sort_values(['passing_english', 'name'])
# Out:
#        name  math  english  reading  passing_english
# 11     Alan    92       62       72            False
# 8    Albert    92       62       87            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True
# 1      Jane    88       79       67             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 2     Suzie    94       74       95             True

# %% [markdown]
# #### d. Sort the english grades first by passing_english, and then by the actual english grade, similar to how we did in the last step.

# %%
df.sort_values(['passing_english', 'english'])
# Out:
#        name  math  english  reading  passing_english
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 2     Suzie    94       74       95             True
# 5      John    79       76       93             True
# 1      Jane    88       79       67             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True

# %% [markdown]
# #### e. Calculate each students overall grade and add it as a column on the dataframe. The overall grade is the average of the math, english, and reading grades.

# %%
df["overall_grade"] = (df.math + df.english + df.reading)/3
df.sort_values(["overall_grade"],ascending=False)
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 10    Isaac    92       99       93             True      94.666667
# 3     Billy    98       96       88             True      94.000000
# 4       Ada    77       92       98             True      89.000000
# 2     Suzie    94       74       95             True      87.666667
# 5      John    79       76       93             True      82.666667
# 7     Marie    93       63       90            False      82.000000
# 9   Richard    69       80       94             True      81.000000
# 8    Albert    92       62       87            False      80.333333
# 1      Jane    88       79       67             True      78.000000
# 0     Sally    62       85       80             True      75.666667
# 6    Thomas    82       64       81            False      75.666667
# 11     Alan    92       62       72            False      75.333333

# %% [markdown]
# ### 2. Load the mpg dataset. Read the documentation for the dataset and use it for the following questions:

# %%
from pydataset import data 
list(data().dataset_id)
# Out:
# ['AirPassengers',
#  'BJsales',
#  'BOD',
#  'Formaldehyde',
#  'HairEyeColor',
#  'InsectSprays',
#  'JohnsonJohnson',
#  'LakeHuron',
#  'LifeCycleSavings',
#  'Nile',
#  'OrchardSprays',
#  'PlantGrowth',
#  'Puromycin',
#  'Titanic',
#  'ToothGrowth',
#  'UCBAdmissions',
#  'UKDriverDeaths',
#  'UKgas',
#  'USAccDeaths',
#  'USArrests',
#  'USJudgeRatings',
#  'USPersonalExpenditure',
#  'VADeaths',
#  'WWWusage',
#  'WorldPhones',
#  'airmiles',
#  'airquality',
#  'anscombe',
#  'attenu',
#  'attitude',
#  'austres',
#  'cars',
#  'chickwts',
#  'co2',
#  'crimtab',
#  'discoveries',
#  'esoph',
#  'euro',
#  'faithful',
#  'freeny',
#  'infert',
#  'iris',
#  'islands',
#  'lh',
#  'longley',
#  'lynx',
#  'morley',
#  'mtcars',
#  'nhtemp',
#  'nottem',
#  'npk',
#  'occupationalStatus',
#  'precip',
#  'presidents',
#  'pressure',
#  'quakes',
#  'randu',
#  'rivers',
#  'rock',
#  'sleep',
#  'stackloss',
#  'sunspot.month',
#  'sunspot.year',
#  'sunspots',
#  'swiss',
# ...

# %%
mpg = data('mpg')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %% [markdown]
# #### a. How many rows and columns are there?

# %%
mpg.shape
# Out:
# (234, 11)

# %% [markdown]
# #### b. What are the data types of each column?

# %%
mpg.dtypes
# Out:
# manufacturer     object
# model            object
# displ           float64
# year              int64
# cyl               int64
# trans            object
# drv              object
# cty               int64
# hwy               int64
# fl               object
# class            object
# dtype: object

# %% [markdown]
# #### c. Summarize the dataframe with .info and .describe

# %%
mpg.info
mpg.describe
# Rows are individial cars that participated in the mpg study.  
# Each subject has its manufacurer, model, displacement(liters), year, number of cylinders, transmission
# wheel drive, the city mpg, highway mpg, fuel type, class of vehicle.
# Out:
# <bound method NDFrame.describe of     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# ...

# %% [markdown]
# #### d. Rename the cty column to city.

# %%
# df.rename(columns={'original_name': 'new_name'})
mpg = mpg.rename(columns={'cty':'city'})
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ...

# %% [markdown]
# #### e. Rename the hwy column to highway.

# %%
# df.rename(columns={'original_name': 'new_name'})
mpg= mpg.rename(columns={'hwy':'highway'})
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class
# 1    compact
# 2    compact
# ...

# %% [markdown]
# #### f. Do any cars have better city mileage than highway mileage?

# %%
# df.sort_values(["overall_grade"],ascending=False)
city_beeter_than_highway = (mpg.city > mpg.highway).sum()
city_beeter_than_highway
# Out:
# 0

# %% [markdown]
# #### g. Create a column named mileage_difference this column should contain the difference between highway and city mileage for each car.

# %%
mpg["mileage_difference"] = (mpg.highway - mpg.city)
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class  mileage_difference
# ...

# %% [markdown]
# #### h. Which car (or cars) has the highest mileage difference?

# %%
mpg.sort_values('mileage_difference', ascending=False).head()
# Out:
#     manufacturer       model  displ  year  cyl     trans drv  city  highway  \
# 107        honda       civic    1.8  2008    4  auto(l5)   f    24       36
# 223   volkswagen  new beetle    1.9  1999    4  auto(l4)   f    29       41
# 1           audi          a4    1.8  1999    4  auto(l5)   f    18       29
# 229   volkswagen      passat    1.8  1999    4  auto(l5)   f    18       29
# 36     chevrolet      malibu    3.5  2008    6  auto(l4)   f    18       29
#
#     fl       class  mileage_difference
# 107  c  subcompact                  12
# 223  d  subcompact                  12
# 1    p     compact                  11
# 229  p     midsize                  11
# 36   r     midsize                  11

# %% [markdown]
# #### i. Which compact class car has the lowest highway mileage? The best?

# %%
compact_car = mpg[mpg['class'] == 'compact']
compact_car
# Out:
#     manufacturer         model  displ  year  cyl       trans drv  city  \
# 1           audi            a4    1.8  1999    4    auto(l5)   f    18
# 2           audi            a4    1.8  1999    4  manual(m5)   f    21
# 3           audi            a4    2.0  2008    4  manual(m6)   f    20
# 4           audi            a4    2.0  2008    4    auto(av)   f    21
# 5           audi            a4    2.8  1999    6    auto(l5)   f    16
# 6           audi            a4    2.8  1999    6  manual(m5)   f    18
# 7           audi            a4    3.1  2008    6    auto(av)   f    18
# 8           audi    a4 quattro    1.8  1999    4  manual(m5)   4    18
# 9           audi    a4 quattro    1.8  1999    4    auto(l5)   4    16
# 10          audi    a4 quattro    2.0  2008    4  manual(m6)   4    20
# 11          audi    a4 quattro    2.0  2008    4    auto(s6)   4    19
# 12          audi    a4 quattro    2.8  1999    6    auto(l5)   4    15
# ...

# %%
compact_car[(compact_car.highway == compact_car.highway.min())]
# Out:
#     manufacturer  model  displ  year  cyl     trans drv  city  highway fl  \
# 220   volkswagen  jetta    2.8  1999    6  auto(l4)   f    16       23  r
#
#        class  mileage_difference
# 220  compact                   7

# %%
compact_car.sort_values('highway', ascending=False).head(2)
# Out:
#     manufacturer    model  displ  year  cyl       trans drv  city  highway fl  \
# 213   volkswagen    jetta    1.9  1999    4  manual(m5)   f    33       44  d
# 197       toyota  corolla    1.8  2008    4  manual(m5)   f    28       37  r
#
#        class  mileage_difference
# 213  compact                  11
# 197  compact                   9

# %% [markdown]
# #### j. Create a column named average_mileage that is the mean of the city and highway mileage.

# %%
mpg["average_mileage"] = (mpg.city + mpg.highway)/2
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %% [markdown]
# #### k. Which dodge car has the best average mileage? The worst?

# %%
dodge_cars = mpg[mpg['manufacturer']== 'dodge']
dodge_cars
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  city  \
# 38        dodge          caravan 2wd    2.4  1999    4    auto(l3)   f    18
# 39        dodge          caravan 2wd    3.0  1999    6    auto(l4)   f    17
# 40        dodge          caravan 2wd    3.3  1999    6    auto(l4)   f    16
# 41        dodge          caravan 2wd    3.3  1999    6    auto(l4)   f    16
# 42        dodge          caravan 2wd    3.3  2008    6    auto(l4)   f    17
# 43        dodge          caravan 2wd    3.3  2008    6    auto(l4)   f    17
# 44        dodge          caravan 2wd    3.3  2008    6    auto(l4)   f    11
# 45        dodge          caravan 2wd    3.8  1999    6    auto(l4)   f    15
# 46        dodge          caravan 2wd    3.8  1999    6    auto(l4)   f    15
# 47        dodge          caravan 2wd    3.8  2008    6    auto(l6)   f    16
# 48        dodge          caravan 2wd    4.0  2008    6    auto(l6)   f    16
# ...

# %%
dodge_cars.sort_values('average_mileage', ascending = False).head(3)
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  city  highway  \
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f    18       24
# 42        dodge  caravan 2wd    3.3  2008    6  auto(l4)   f    17       24
# 43        dodge  caravan 2wd    3.3  2008    6  auto(l4)   f    17       24
#
#    fl    class  mileage_difference  average_mileage
# 38  r  minivan                   6             21.0
# 42  r  minivan                   7             20.5
# 43  r  minivan                   7             20.5

# %%
dodge_cars.sort_values('average_mileage').head()
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  city  \
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
# 66        dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 60        dodge          durango 4wd    4.7  2008    8    auto(l5)   4     9
# 55        dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4     9
# 74        dodge  ram 1500 pickup 4wd    5.9  1999    8    auto(l4)   4    11
#
#     highway fl   class  mileage_difference  average_mileage
# 70       12  e  pickup                   3             10.5
# 66       12  e  pickup                   3             10.5
# 60       12  e     suv                   3             10.5
# 55       12  e  pickup                   3             10.5
# 74       15  r  pickup                   4             13.0

# %% [markdown]
# ### 3. Load the Mammals dataset. Read the documentation for it, and use the data to answer these questions:

# %%
Mammals = data('Mammals')
Mammals
# Out:
#        weight  speed  hoppers  specials
# 1    6000.000   35.0    False     False
# 2    4000.000   26.0    False     False
# 3    3000.000   25.0    False     False
# 4    1400.000   45.0    False     False
# 5     400.000   70.0    False     False
# 6     350.000   70.0    False     False
# 7     300.000   64.0    False     False
# 8     260.000   70.0    False     False
# 9     250.000   40.0    False     False
# 10   3800.000   25.0    False      True
# 11   1000.000   60.0    False     False
# 12    900.000   70.0    False     False
# 13    900.000   56.0    False     False
# 14    800.000   29.0    False     False
# 15    750.000   57.0    False     False
# 16    500.000   32.0    False     False
# 17    450.000   56.0    False     False
# 18    300.000   72.0    False     False
# 19    300.000   90.0    False     False
# 20    250.000   80.0    False     False
# 21    250.000   56.0    False     False
# 22    170.000   80.0    False     False
# ...

# %% [markdown]
# #### a. How many rows and columns are there?

# %%
Mammals.shape
# Out:
# (107, 4)

# %% [markdown]
# #### b. What are the data types?

# %%
Mammals.dtypes
# Out:
# weight      float64
# speed       float64
# hoppers        bool
# specials       bool
# dtype: object

# %% [markdown]
# #### c. Summarize the dataframe with .info and .describe

# %%
Mammals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB

# %%
Mammals.describe()
# Out:
#             weight       speed
# count   107.000000  107.000000
# mean    278.688178   46.208411
# std     839.608269   26.716778
# min       0.016000    1.600000
# 25%       1.700000   22.500000
# 50%      34.000000   48.000000
# 75%     142.500000   65.000000
# max    6000.000000  110.000000

# %% [markdown]
# #### d. What is the the weight of the fastest animal?

# %%
Mammals.sort_values(['speed'], ascending = False).head(1)
# Out:
#     weight  speed  hoppers  specials
# 53    55.0  110.0    False     False

# %% [markdown]
# #### e. What is the overal percentage of specials?

# %%
specials_2 = Mammals[Mammals['specials']== True]
specials_2
# Out:
#      weight  speed  hoppers  specials
# 10   3800.0   25.0    False      True
# 59     12.0   24.0    False      True
# 60     11.0   30.0    False      True
# 65      5.0   27.0    False      True
# 66      3.0   16.0    False      True
# 68     70.0   40.0    False      True
# 69     13.0   37.0    False      True
# 70      9.0    3.2    False      True
# 105     5.0    7.4    False      True
# 107     4.0    1.6    False      True

# %%
percentage_of_specials = (specials_2.count() / Mammals.count()) * 100
percentage_of_specials
# Out:
# weight      9.345794
# speed       9.345794
# hoppers     9.345794
# specials    9.345794
# dtype: float64

# %% [markdown]
# #### f. How many animals are hoppers that are above the median speed? What percentage is this?

# %%
Mammals_median = Mammals.speed.median()
over_median = Mammals[Mammals.speed > Mammals_median]
over_median.count()
# Out:
# weight      53
# speed       53
# hoppers     53
# specials    53
# dtype: int64

# %%
hoppers_over_median = Mammals[Mammals.speed > Mammals_median][Mammals.hoppers]
len(hoppers_over_median)
# Out:
# /var/folders/w8/3pzw7rq50zv8f2wgdz4pgqdr0000gn/T/ipykernel_989/961730260.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   hoppers_over_median = Mammals[Mammals.speed > Mammals_median][Mammals.hoppers]
# 7

# %%
percent_fast_hoppers = (len(hoppers_over_median) / Mammals.count()) * 100
percent_fast_hoppers
# Out:
# weight      6.542056
# speed       6.542056
# hoppers     6.542056
# specials    6.542056
# dtype: float64
